# %%
url = "https://goo.gl/vhm1eU"
names = ['preg', 'plas', 'pres', 'skin', 'test', 
         'mass', 'pedi', 'age', 'class'] 
data = pd.read_csv(url, names=names)
data[:10]
# Out:
#    preg  plas  pres  skin  test  mass   pedi  age  class
# 0     6   148    72    35     0  33.6  0.627   50      1
# 1     1    85    66    29     0  26.6  0.351   31      0
# 2     8   183    64     0     0  23.3  0.672   32      1
# 3     1    89    66    23    94  28.1  0.167   21      0
# 4     0   137    40    35   168  43.1  2.288   33      1
# 5     5   116    74     0     0  25.6  0.201   30      0
# 6     3    78    50    32    88  31.0  0.248   26      1
# 7    10   115     0     0     0  35.3  0.134   29      0
# 8     2   197    70    45   543  30.5  0.158   53      1
# 9     8   125    96     0     0   0.0  0.232   54      1

# %%
data.hist(color='k',alpha=0.5, bins=50,figsize=(15,15))
plt.show()

# %% [markdown]
# ---

# %%
array = data.values

# %%
array[:10]
# Out:
# array([[6.0, 148.0, 72.0, 35.0, 0.0, 33.6, 0.627, 50.0, 1.0],
#        [1.0, 85.0, 66.0, 29.0, 0.0, 26.6, 0.351, 31.0, 0.0],
#        [8.0, 183.0, 64.0, 0.0, 0.0, 23.3, 0.672, 32.0, 1.0],
#        [1.0, 89.0, 66.0, 23.0, 94.0, 28.1, 0.167, 21.0, 0.0],
#        [0.0, 137.0, 40.0, 35.0, 168.0, 43.1, 2.288, 33.0, 1.0],
#        [5.0, 116.0, 74.0, 0.0, 0.0, 25.6, 0.201, 30.0, 0.0],
#        [3.0, 78.0, 50.0, 32.0, 88.0, 31.0, 0.248, 26.0, 1.0],
#        [10.0, 115.0, 0.0, 0.0, 0.0, 35.3, 0.134, 29.0, 0.0],
#        [2.0, 197.0, 70.0, 45.0, 543.0, 30.5, 0.158, 53.0, 1.0],
#        [8.0, 125.0, 96.0, 0.0, 0.0, 0.0, 0.232, 54.0, 1.0]])

# %% [markdown]
# ---

# %% [markdown]
# ## StandardScaler

# %%
#np.set_printoptions(precision=3)
#np.set_printoptions(threshold=np.inf)
np.set_printoptions(formatter={'float_kind':'{:}'.format})

array = data.values
array[0:10]
# Out:
# array([[6.0, 148.0, 72.0, 35.0, 0.0, 33.6, 0.627, 50.0, 1.0],
#        [1.0, 85.0, 66.0, 29.0, 0.0, 26.6, 0.351, 31.0, 0.0],
#        [8.0, 183.0, 64.0, 0.0, 0.0, 23.3, 0.672, 32.0, 1.0],
#        [1.0, 89.0, 66.0, 23.0, 94.0, 28.1, 0.167, 21.0, 0.0],
#        [0.0, 137.0, 40.0, 35.0, 168.0, 43.1, 2.288, 33.0, 1.0],
#        [5.0, 116.0, 74.0, 0.0, 0.0, 25.6, 0.201, 30.0, 0.0],
#        [3.0, 78.0, 50.0, 32.0, 88.0, 31.0, 0.248, 26.0, 1.0],
#        [10.0, 115.0, 0.0, 0.0, 0.0, 35.3, 0.134, 29.0, 0.0],
#        [2.0, 197.0, 70.0, 45.0, 543.0, 30.5, 0.158, 53.0, 1.0],
#        [8.0, 125.0, 96.0, 0.0, 0.0, 0.0, 0.232, 54.0, 1.0]])

# %%
#np.set_printoptions(precision=3)
np.set_printoptions(threshold=np.inf)
#np.set_printoptions(formatter={'float_kind':'{:}'.format})

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(array)
rescaled_array = scaler.transform(array)
print(rescaled_array[:10])
# Out:
# [[ 0.64   0.848  0.15   0.907 -0.693  0.204  0.468  1.426  1.366]
#  [-0.845 -1.123 -0.161  0.531 -0.693 -0.684 -0.365 -0.191 -0.732]
#  [ 1.234  1.944 -0.264 -1.288 -0.693 -1.103  0.604 -0.106  1.366]
#  [-0.845 -0.998 -0.161  0.155  0.123 -0.494 -0.921 -1.042 -0.732]
#  [-1.142  0.504 -1.505  0.907  0.766  1.41   5.485 -0.02   1.366]
#  [ 0.343 -0.153  0.253 -1.288 -0.693 -0.811 -0.818 -0.276 -0.732]
#  [-0.251 -1.342 -0.988  0.719  0.071 -0.126 -0.676 -0.616  1.366]
#  [ 1.828 -0.184 -3.573 -1.288 -0.693  0.42  -1.02  -0.361 -0.732]
#  [-0.548  2.382  0.046  1.535  4.022 -0.189 -0.948  1.681  1.366]
#  [ 1.234  0.128  1.39  -1.288 -0.693 -4.06  -0.724  1.766  1.366]]

# %%
plt.hist(array)
plt.show()
plt.hist(rescaled_array)
plt.show()

# %% [markdown]
# ---

# %%
#np.set_printoptions(precision=3)
#np.set_printoptions(threshold=1000)
#np.set_printoptions(formatter={'float_kind':'{:}'.format})

# %%
import pandas as pd
import numpy as np
import pprint

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
